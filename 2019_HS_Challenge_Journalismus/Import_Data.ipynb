# %%
import pandas as pd
import numpy as np
import os
# !pip install psycopg2
import psycopg2 as pg
import pandas.io.sql as sql
import sqlalchemy
# Out:
# Requirement already satisfied: psycopg2 in /opt/conda/lib/python3.7/site-packages (2.8.3)

# %%
# host is the bridge gateway of dbnet
DB_HOST = "192.168.0.1" 
DB_PORT = "5432"
DB_NAME = "journalismus_db"
DB_SCHEMA = ""
DB_ADMIN_USER = "db_admin" 
DB_ADMIN_PASSWORD = "db_admin_0815_pw" 
DB_USER = "db_user" 
DB_PASSWORD = "db_user_pw"
DB_USER_GRANTS = "SELECT" #"SELECT, INSERT, UPDATE, DELETE"

zip_file = "data.zip"
zip_file_dir = "./data"
table_file_ending = ".csv"
table_file_delimiter = ","
# definition of special types
table_field_configs = {}

type_mapping = {
    "int64": "BIGINT",
    "float64": "FLOAT",
    "object": "TEXT"
}

class DBConfig:
    db_str = None
    tables = set()
    
    def __init__(self, db_host = DB_HOST, db_port = DB_PORT, db_name = DB_NAME, db_schema = DB_SCHEMA, db_admin_user = DB_ADMIN_USER, db_admin_password = DB_ADMIN_PASSWORD, db_user = DB_USER, db_password = DB_PASSWORD, db_user_grants = DB_USER_GRANTS):
        self.db_host = db_host
        self.db_port = db_port
        self.db_name = db_name
        self.db_schema = db_schema
        self.db_admin_user = db_admin_user
        self.db_admin_password = db_admin_password
        self.db_user = db_user
        self.db_password = db_password
        self.db_user_grants = db_user_grants
        
        self.create_db()
        
        self.db_str = 'postgresql://{username}:{password}@{host}:{port}/{dbname}'.format(username=db_admin_user,password=db_admin_password,host=db_host,port=db_port,dbname=db_name)
        print("Using db connection "+self.db_str)
        
        self.conn = pg.connect(self.db_str)
        self.conn.autocommit = True
        self.cur = self.conn.cursor()
        self.engine = sqlalchemy.create_engine(self.db_str)
    
    def dispose(self):
        # close communication with the PostgreSQL database server
        self.cur.close()
        self.cur = None
        # commit the changes
        self.conn.commit()
        # close the connection
        self.conn.close()
        self.conn = None
        
        self.engine.dispose()
        
    def create_db(self):
        db_str = 'postgresql://{username}:{password}@{host}:{port}'.format(username=self.db_admin_user,password=self.db_admin_password,host=self.db_host,port=self.db_port)
        print("Using db connection "+db_str+" for DB creation.")
        
        conn = pg.connect(db_str)
        conn.autocommit = True
        cur = conn.cursor()   
        
        drop_command = "DROP DATABASE IF EXISTS " +self.db_name
        create_command = "CREATE DATABASE " +self.db_name
        cur.execute(drop_command)
        cur.execute(create_command)
        conn.commit()
        
        drop_command = "DROP ROLE IF EXISTS " +self.db_user
        create_command = "CREATE ROLE " +self.db_user +" LOGIN PASSWORD '" + self.db_password +"'"
        cur.execute(drop_command)
        cur.execute(create_command)
        conn.commit()
        
        grant_command_01 = "GRANT USAGE ON SCHEMA public TO "+ self.db_user
        grant_command_02 = "ALTER DEFAULT PRIVILEGES IN SCHEMA public GRANT "+ self.db_user_grants +" ON TABLES TO "+ self.db_user
        cur.execute(grant_command_01)
        cur.execute(grant_command_02)
        conn.commit()
        
        if self.db_schema is not None and "" != self.db_schema:
            drop_command = "DROP SCHEMA IF EXISTS "+ self.db_schema
            create_command = "CREATE SCHEMA "+ self.db_schema
            cur.execute(drop_command)
            cur.execute(create_command)
            conn.commit()
    
        cur.close()
        conn.close()
        
class TableConfig:
    name = None
    content = None
    types = {}
    
    def get_table_name(self, db_config):
        if db_config.db_schema is None or "" is db_config.db_schema:
            return self.name.lower()
        else:
            return db_config.db_schema.lower() + "." + self.name.lower()
    
    
def define_types(table_config, table_fields_config):
    print("Handle table '"+ table_config.name +"'")
    first_column = True
    table_config.content.columns = table_config.content.columns.str.lower()
    
    for column in table_config.content.columns[0:]:
        print("Handle field '"+ table_config.get_table_name(db_config) + "."+ column +"'.")
        if table_fields_config is not None:
            field_config = table_fields_config.get(column, None)
            
            if field_config is not None:
                for key, value in field_config.items():
                    print("Handle field '"+ table_config.name + "."+ column +"' having '"+ str(key) +" = "+ str(value) +"'.")
                    
                    if "format" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of type date.")
                        table_config.content[column] = pd.to_datetime(table_config.content[column], format=value)
                        table_config.content[column] = table_config.content[column].apply(lambda x: x.date())
                        
                        table_config.types[column] = "DATE"
                        if "%H" in key:
                            table_config.types[column] = "TIMESTAMP"
                        
                    elif "numeric" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of numeric type.")
                        table_config.content[column] = pd.to_numeric(table_config.content[column], errors='coerce')
                    elif "type" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of type = '"+str(value) +"'.'")
                        table_config.content[column] = table_config.content[column].astype(value)
                    else:
                        print("!!!!\Field '"+ table_config.name +"."+ column +"' has an unknown conversion defined '"+ str(key) +" = "+ str(value) +"'.\n!!!!")

        if column not in table_config.types:
            typ = type_mapping.get(str(table_config.content[column].dtype), None)
            
            if typ is not None:
                table_config.types[column] = typ

            else:
                print("!!!!\nThere is not type defined for '"+str(table_config.content[column].dtype) +" in "+ str(type_mapping) +"'.\n!!!!")

            
        if first_column:
            #print("Table "+ table_config.name +" has index "+ column)
            #table_config.content.set_index(column, inplace=True, verify_integrity=True)
            first_column = False
             
                
def create_table(db_config, table_config):
    drop_command = "DROP TABLE IF EXISTS "+ table_config.get_table_name(db_config)
    create_command = "CREATE TABLE IF NOT EXISTS "+ table_config.get_table_name(db_config) +" ("
    #grant_command_01 = "GRANT "+ db_config.db_user_grants +" ON ALL TABLES IN SCHEMA "+ db_config.db_name +" TO "+ db_config.db_user
    #grant_command_01 = "GRANT ALL PRIVILEGES ON DATABASE "+ db_config.db_name +" TO "+ db_config.db_user
    #grant_command_01 = "GRANT "+ db_config.db_user_grants +" PRIVILEGES ON ALL TABLES IN SCHEMA public TO "+ db_config.db_user
    #grant_command_02 = "GRANT "+ db_config.db_user_grants +" PRIVILEGES ON ALL SEQUENCES IN SCHEMA public TO "+ db_config.db_user
    grant_command_01 = "GRANT "+ db_config.db_user_grants +" ON ALL TABLES IN SCHEMA public TO "+ db_config.db_user
    
    first_column = True
    column = table_config.content.columns[0]
    if not table_config.content[column].is_unique:
        create_command += "index INT PRIMARY KEY NOT NULL"
        first_column = False
        
    for column in table_config.content.columns[0:]:
        print("Handle field '"+ table_config.get_table_name(db_config) + "."+ column +"' being of type '"+ str(table_config.content[column].dtype) +"'.")
        
        if not first_column:
            create_command += ","
            
        create_command += column + " "
        create_command += str(table_config.types[column])
        table_name_index = column.find("_id")
        
        if first_column:
            create_command += " PRIMARY KEY NOT NULL"
            table_config.content.set_index(column, inplace=True, verify_integrity=True)
            first_column = False
        elif table_name_index != -1:
            table_name = column[:table_name_index]
            if table_name in db_config.tables:
                create_command += " NOT NULL REFERENCES " + table_name
            else:
                print("Field "+ column +" seems to reference table "+ table_name +" but this table does not exist.")
                
    create_command += ")"
    
    print("Execute "+ drop_command)
    db_config.cur.execute(drop_command)
    print("Execute "+ create_command)
    db_config.cur.execute(create_command)
    print("Execute "+ grant_command_01)
    db_config.cur.execute(grant_command_01)
    #print("Execute "+ grant_command_02)
    #db_config.cur.execute(grant_command_02)
    db_config.conn.commit()
    db_config.tables.add(table_config.name)
    
def add_data(db_config, table_config):
    if db_config.db_schema is None or db_config.db_schema == "":
        table_config.content.to_sql(table_config.name, db_config.engine, if_exists='append', chunksize=1000)
    else:
        table_config.content.to_sql(table_config.name, db_config.engine, schema=db_config.db_schema, if_exists='append', chunksize=1000)

# %%
# unpack the zip file
from shutil import unpack_archive
os.makedirs(zip_file_dir, exist_ok=True)
unpack_archive(zip_file, '.')

db_config = DBConfig()

for root, dirs, files in os.walk(zip_file_dir):
    files.sort()
    for file in files:
        if file.endswith(table_file_ending):
            table_config = TableConfig()
            table_name = os.path.splitext(file)[0]
            table_name_index = table_name.find("_")
            
            if table_name_index != -1 and table_name[:table_name_index].isdigit():
                table_name = table_name[table_name_index+1:]
            
            table_config.name = table_name
            table = pd.read_csv(os.path.join(root, file), delimiter=table_file_delimiter)
            table_config.content = table  
            #print("Read table content of '"+table_config.name +"'.")
            
            define_types(table_config, table_field_configs.get(table_config.name, None))
            create_table(db_config, table_config)
            add_data(db_config, table_config)

# remove data files
from shutil import rmtree
rmtree(zip_file_dir, ignore_errors=True)

db_config.dispose()
# Out:
# Using db connection postgresql://db_admin:db_admin_0815_pw@192.168.0.1:5432 for DB creation.
# Using db connection postgresql://db_admin:db_admin_0815_pw@192.168.0.1:5432/journalismus_db
# Handle table 'aiddata_donor_recipient_year'
# Handle field 'aiddata_donor_recipient_year.donor'.
# Handle field 'aiddata_donor_recipient_year.recipient'.
# Handle field 'aiddata_donor_recipient_year.year'.
# Handle field 'aiddata_donor_recipient_year.commitment_amount_usd_constant_sum'.
# Handle field 'aiddata_donor_recipient_year.donor' being of type 'object'.
# Handle field 'aiddata_donor_recipient_year.recipient' being of type 'object'.
# Handle field 'aiddata_donor_recipient_year.year' being of type 'int64'.
# Handle field 'aiddata_donor_recipient_year.commitment_amount_usd_constant_sum' being of type 'int64'.
# Execute DROP TABLE IF EXISTS aiddata_donor_recipient_year
# Execute CREATE TABLE IF NOT EXISTS aiddata_donor_recipient_year (index INT PRIMARY KEY NOT NULL,donor TEXT,recipient TEXT,year BIGINT,commitment_amount_usd_constant_sum BIGINT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'aiddata_donor_recipient_year_purpose'
# Handle field 'aiddata_donor_recipient_year_purpose.donor'.
# Handle field 'aiddata_donor_recipient_year_purpose.recipient'.
# Handle field 'aiddata_donor_recipient_year_purpose.year'.
# Handle field 'aiddata_donor_recipient_year_purpose.coalesced_purpose_code'.
# Handle field 'aiddata_donor_recipient_year_purpose.coalesced_purpose_name'.
# Handle field 'aiddata_donor_recipient_year_purpose.commitment_amount_usd_constant_sum'.
# Handle field 'aiddata_donor_recipient_year_purpose.donor' being of type 'object'.
# Handle field 'aiddata_donor_recipient_year_purpose.recipient' being of type 'object'.
# Handle field 'aiddata_donor_recipient_year_purpose.year' being of type 'int64'.
# Handle field 'aiddata_donor_recipient_year_purpose.coalesced_purpose_code' being of type 'float64'.
# Handle field 'aiddata_donor_recipient_year_purpose.coalesced_purpose_name' being of type 'object'.
# Handle field 'aiddata_donor_recipient_year_purpose.commitment_amount_usd_constant_sum' being of type 'int64'.
# Execute DROP TABLE IF EXISTS aiddata_donor_recipient_year_purpose
# Execute CREATE TABLE IF NOT EXISTS aiddata_donor_recipient_year_purpose (index INT PRIMARY KEY NOT NULL,donor TEXT,recipient TEXT,year BIGINT,coalesced_purpose_code FLOAT,coalesced_purpose_name TEXT,commitment_amount_usd_constant_sum BIGINT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'aiddata_full'
# Handle field 'aiddata_full.aiddata_id'.
# Handle field 'aiddata_full.aiddata_2_id'.
# Handle field 'aiddata_full.year'.
# Handle field 'aiddata_full.donor'.
# Handle field 'aiddata_full.donor_iso'.
# Handle field 'aiddata_full.donor_region'.
# Handle field 'aiddata_full.implementing_agency'.
# Handle field 'aiddata_full.financing_agency'.
# Handle field 'aiddata_full.crs_bi_multi'.
# Handle field 'aiddata_full.recipient'.
# Handle field 'aiddata_full.recipient_iso'.
# Handle field 'aiddata_full.recipient_region'.
# Handle field 'aiddata_full.start_date'.
# Handle field 'aiddata_full.end_date'.
# Handle field 'aiddata_full.commitment_date'.
# Handle field 'aiddata_full.planned_start_date'.
# Handle field 'aiddata_full.planned_end_date'.
# Handle field 'aiddata_full.title'.
# Handle field 'aiddata_full.short_description'.
# Handle field 'aiddata_full.long_description'.
# Handle field 'aiddata_full.donor_project_id'.
# Handle field 'aiddata_full.donor_secondary_id'.
# Handle field 'aiddata_full.aiddata_sector_code'.
# Handle field 'aiddata_full.aiddata_sector_name'.
# Handle field 'aiddata_full.aiddata_purpose_code'.
# Handle field 'aiddata_full.aiddata_purpose_name'.
# Handle field 'aiddata_full.aiddata_activity_codes'.
# Handle field 'aiddata_full.aiddata_activity_names'.
# Handle field 'aiddata_full.flow_name'.
# Handle field 'aiddata_full.crs_sector_code'.
# Handle field 'aiddata_full.crs_sector_name'.
# Handle field 'aiddata_full.crs_purpose_code'.
# Handle field 'aiddata_full.crs_purpose_name'.
# Handle field 'aiddata_full.coalesced_purpose_code'.
# Handle field 'aiddata_full.coalesced_purpose_name'.
# Handle field 'aiddata_full.commitment_amount_usd_constant'.
# Handle field 'aiddata_full.commitment_amount_usd_current'.
# Handle field 'aiddata_full.total_project_cost'.
# Handle field 'aiddata_full.crs_trade'.
# Handle field 'aiddata_full.crs_climate'.
# Handle field 'aiddata_full.crs_biodiversity'.
# Handle field 'aiddata_full.crs_gender'.
# Handle field 'aiddata_full.crs_environment'.
# Handle field 'aiddata_full.crs_desertification'.
# Handle field 'aiddata_full.pdgg'.
# Handle field 'aiddata_full.channel_code'.
# Handle field 'aiddata_full.finance_t'.
# Handle field 'aiddata_full.associated_financing'.
# Handle field 'aiddata_full.future_ds_principal_amount_usd_nominal'.
# Handle field 'aiddata_full.future_ds_interest_amount_usd_nominal'.
# Handle field 'aiddata_full.received_amount_usd_nominal'.
# Handle field 'aiddata_full.irtc_amount_usd_nominal'.
# Handle field 'aiddata_full.untied_amount_usd_nominal'.
# Handle field 'aiddata_full.tied_amount_usd_nominal'.
# Handle field 'aiddata_full.partial_tied_amount_usd_nominal'.
# Handle field 'aiddata_full.arrears_interest_amount_usd_nominal'.
# Handle field 'aiddata_full.arrears_principal_amount_usd_nominal'.
# Handle field 'aiddata_full.initial_report'.
# Handle field 'aiddata_full.ftc'.
# Handle field 'aiddata_full.repay_type'.
# Handle field 'aiddata_full.outstanding_amount_usd_nominal'.
# Handle field 'aiddata_full.interest_amount_usd_nominal'.
# Handle field 'aiddata_full.expert_commitment_amount_usd_nominal'.
# Handle field 'aiddata_full.export_credit_amount_usd_nominal'.
# Handle field 'aiddata_full.expert_extended_amount_usd_nominal'.
# Handle field 'aiddata_full.additional_info'.
# Handle field 'aiddata_full.source'.
# Handle field 'aiddata_full.source_detail'.
# Handle field 'aiddata_full.aiddata_id' being of type 'int64'.
# Handle field 'aiddata_full.aiddata_2_id' being of type 'float64'.
# Field aiddata_2_id seems to reference table aiddata_2 but this table does not exist.
# Handle field 'aiddata_full.year' being of type 'int64'.
# Handle field 'aiddata_full.donor' being of type 'object'.
# Handle field 'aiddata_full.donor_iso' being of type 'object'.
# Handle field 'aiddata_full.donor_region' being of type 'object'.
# Handle field 'aiddata_full.implementing_agency' being of type 'object'.
# Handle field 'aiddata_full.financing_agency' being of type 'object'.
# Handle field 'aiddata_full.crs_bi_multi' being of type 'float64'.
# Handle field 'aiddata_full.recipient' being of type 'object'.
# Handle field 'aiddata_full.recipient_iso' being of type 'object'.
# Handle field 'aiddata_full.recipient_region' being of type 'object'.
# Handle field 'aiddata_full.start_date' being of type 'object'.
# Handle field 'aiddata_full.end_date' being of type 'object'.
# Handle field 'aiddata_full.commitment_date' being of type 'object'.
# Handle field 'aiddata_full.planned_start_date' being of type 'float64'.
# Handle field 'aiddata_full.planned_end_date' being of type 'float64'.
# Handle field 'aiddata_full.title' being of type 'object'.
# Handle field 'aiddata_full.short_description' being of type 'object'.
# Handle field 'aiddata_full.long_description' being of type 'object'.
# Handle field 'aiddata_full.donor_project_id' being of type 'object'.
# Field donor_project_id seems to reference table donor_project but this table does not exist.
# Handle field 'aiddata_full.donor_secondary_id' being of type 'object'.
# Field donor_secondary_id seems to reference table donor_secondary but this table does not exist.
# Handle field 'aiddata_full.aiddata_sector_code' being of type 'float64'.
# Handle field 'aiddata_full.aiddata_sector_name' being of type 'object'.
# Handle field 'aiddata_full.aiddata_purpose_code' being of type 'float64'.
# Handle field 'aiddata_full.aiddata_purpose_name' being of type 'object'.
# Handle field 'aiddata_full.aiddata_activity_codes' being of type 'object'.
# Handle field 'aiddata_full.aiddata_activity_names' being of type 'object'.
# Handle field 'aiddata_full.flow_name' being of type 'object'.
# Handle field 'aiddata_full.crs_sector_code' being of type 'float64'.
# Handle field 'aiddata_full.crs_sector_name' being of type 'object'.
# Handle field 'aiddata_full.crs_purpose_code' being of type 'float64'.
# Handle field 'aiddata_full.crs_purpose_name' being of type 'object'.
# Handle field 'aiddata_full.coalesced_purpose_code' being of type 'int64'.
# Handle field 'aiddata_full.coalesced_purpose_name' being of type 'object'.
# Handle field 'aiddata_full.commitment_amount_usd_constant' being of type 'int64'.
# Handle field 'aiddata_full.commitment_amount_usd_current' being of type 'float64'.
# Handle field 'aiddata_full.total_project_cost' being of type 'float64'.
# Handle field 'aiddata_full.crs_trade' being of type 'float64'.
# Handle field 'aiddata_full.crs_climate' being of type 'float64'.
# Handle field 'aiddata_full.crs_biodiversity' being of type 'float64'.
# Handle field 'aiddata_full.crs_gender' being of type 'float64'.
# Handle field 'aiddata_full.crs_environment' being of type 'float64'.
# Handle field 'aiddata_full.crs_desertification' being of type 'float64'.
# Handle field 'aiddata_full.pdgg' being of type 'float64'.
# Handle field 'aiddata_full.channel_code' being of type 'float64'.
# Handle field 'aiddata_full.finance_t' being of type 'object'.
# Handle field 'aiddata_full.associated_financing' being of type 'float64'.
# Handle field 'aiddata_full.future_ds_principal_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.future_ds_interest_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.received_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.irtc_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.untied_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.tied_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.partial_tied_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.arrears_interest_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.arrears_principal_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.initial_report' being of type 'float64'.
# Handle field 'aiddata_full.ftc' being of type 'float64'.
# Handle field 'aiddata_full.repay_type' being of type 'float64'.
# Handle field 'aiddata_full.outstanding_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.interest_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.expert_commitment_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.export_credit_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.expert_extended_amount_usd_nominal' being of type 'float64'.
# Handle field 'aiddata_full.additional_info' being of type 'object'.
# Handle field 'aiddata_full.source' being of type 'object'.
# Handle field 'aiddata_full.source_detail' being of type 'object'.
# Execute DROP TABLE IF EXISTS aiddata_full
# Execute CREATE TABLE IF NOT EXISTS aiddata_full (aiddata_id BIGINT PRIMARY KEY NOT NULL,aiddata_2_id FLOAT,year BIGINT,donor TEXT,donor_iso TEXT,donor_region TEXT,implementing_agency TEXT,financing_agency TEXT,crs_bi_multi FLOAT,recipient TEXT,recipient_iso TEXT,recipient_region TEXT,start_date TEXT,end_date TEXT,commitment_date TEXT,planned_start_date FLOAT,planned_end_date FLOAT,title TEXT,short_description TEXT,long_description TEXT,donor_project_id TEXT,donor_secondary_id TEXT,aiddata_sector_code FLOAT,aiddata_sector_name TEXT,aiddata_purpose_code FLOAT,aiddata_purpose_name TEXT,aiddata_activity_codes TEXT,aiddata_activity_names TEXT,flow_name TEXT,crs_sector_code FLOAT,crs_sector_name TEXT,crs_purpose_code FLOAT,crs_purpose_name TEXT,coalesced_purpose_code FLOAT,coalesced_purpose_name TEXT,commitment_amount_usd_constant BIGINT,commitment_amount_usd_current FLOAT,total_project_cost FLOAT,crs_trade FLOAT,crs_climate FLOAT,crs_biodiversity FLOAT,crs_gender FLOAT,crs_environment FLOAT,crs_desertification FLOAT,pdgg FLOAT,channel_code FLOAT,finance_t TEXT,associated_financing FLOAT,future_ds_principal_amount_usd_nominal FLOAT,future_ds_interest_amount_usd_nominal FLOAT,received_amount_usd_nominal FLOAT,irtc_amount_usd_nominal FLOAT,untied_amount_usd_nominal FLOAT,tied_amount_usd_nominal FLOAT,partial_tied_amount_usd_nominal FLOAT,arrears_interest_amount_usd_nominal FLOAT,arrears_principal_amount_usd_nominal FLOAT,initial_report FLOAT,ftc FLOAT,repay_type FLOAT,outstanding_amount_usd_nominal FLOAT,interest_amount_usd_nominal FLOAT,expert_commitment_amount_usd_nominal FLOAT,export_credit_amount_usd_nominal FLOAT,expert_extended_amount_usd_nominal FLOAT,additional_info TEXT,source TEXT,source_detail TEXT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'aiddata_thin'
# Handle field 'aiddata_thin.aiddata_id'.
# Handle field 'aiddata_thin.aiddata_2_id'.
# Handle field 'aiddata_thin.year'.
# Handle field 'aiddata_thin.donor'.
# Handle field 'aiddata_thin.recipient'.
# Handle field 'aiddata_thin.commitment_amount_usd_constant'.
# Handle field 'aiddata_thin.coalesced_purpose_code'.
# Handle field 'aiddata_thin.coalesced_purpose_name'.
# Handle field 'aiddata_thin.aiddata_id' being of type 'int64'.
# Handle field 'aiddata_thin.aiddata_2_id' being of type 'float64'.
# Field aiddata_2_id seems to reference table aiddata_2 but this table does not exist.
# Handle field 'aiddata_thin.year' being of type 'int64'.
# Handle field 'aiddata_thin.donor' being of type 'object'.
# Handle field 'aiddata_thin.recipient' being of type 'object'.
# Handle field 'aiddata_thin.commitment_amount_usd_constant' being of type 'int64'.
# Handle field 'aiddata_thin.coalesced_purpose_code' being of type 'int64'.
# Handle field 'aiddata_thin.coalesced_purpose_name' being of type 'object'.
# Execute DROP TABLE IF EXISTS aiddata_thin
# Execute CREATE TABLE IF NOT EXISTS aiddata_thin (aiddata_id BIGINT PRIMARY KEY NOT NULL,aiddata_2_id FLOAT,year BIGINT,donor TEXT,recipient TEXT,commitment_amount_usd_constant BIGINT,coalesced_purpose_code FLOAT,coalesced_purpose_name TEXT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
