# %%
import pandas as pd
import numpy as np
import os
# !pip install psycopg2
import psycopg2 as pg
import pandas.io.sql as sql
import sqlalchemy
# Out:
# Requirement already satisfied: psycopg2 in /opt/conda/lib/python3.7/site-packages (2.8.3)

# %%
# host is the bridge gateway of dbnet
DB_HOST = "192.168.0.1" 
DB_PORT = "5432"
DB_NAME = "bank_db"
DB_SCHEMA = ""
DB_ADMIN_USER = "db_admin" 
DB_ADMIN_PASSWORD = "db_admin_0815_pw" 
DB_USER = "db_user" 
DB_PASSWORD = "db_user_pw"
DB_USER_GRANTS = "SELECT" #"SELECT, INSERT, UPDATE, DELETE"

zip_file = "data.zip"
zip_file_dir = "./data"
table_file_ending = ".asc"
table_file_delimiter = ";"
# definition of special types
table_field_configs = {
    "account": {
        "date": {
            "format": "%y%m%d"
        }
    },
    "card": {
        "issued": {
            "format": "%y%m%d %H:%M:%S"
        }
    },
    "district": {
        "a12": {
            "numeric": ""
        },
        "a15": {
            "numeric": ""
        }
    },
    "loan": {
        "date": {
            "format": "%y%m%d"
        }
    },
    "trans": {
        "date": {
            "format": "%y%m%d"
        }
    }
}

type_mapping = {
    "int64": "INT",
    "float64": "FLOAT",
    "object": "TEXT"
}

class DBConfig:
    db_str = None
    tables = set()
    
    def __init__(self, db_host = DB_HOST, db_port = DB_PORT, db_name = DB_NAME, db_schema = DB_SCHEMA, db_admin_user = DB_ADMIN_USER, db_admin_password = DB_ADMIN_PASSWORD, db_user = DB_USER, db_password = DB_PASSWORD, db_user_grants = DB_USER_GRANTS):
        self.db_host = db_host
        self.db_port = db_port
        self.db_name = db_name
        self.db_schema = db_schema
        self.db_admin_user = db_admin_user
        self.db_admin_password = db_admin_password
        self.db_user = db_user
        self.db_password = db_password
        self.db_user_grants = db_user_grants
        
        self.create_db()
        
        self.db_str = 'postgresql://{username}:{password}@{host}:{port}/{dbname}'.format(username=db_admin_user,password=db_admin_password,host=db_host,port=db_port,dbname=db_name)
        print("Using db connection "+self.db_str)
        
        self.conn = pg.connect(self.db_str)
        self.conn.autocommit = True
        self.cur = self.conn.cursor()
        self.engine = sqlalchemy.create_engine(self.db_str)
    
    def dispose(self):
        # close communication with the PostgreSQL database server
        self.cur.close()
        self.cur = None
        # commit the changes
        self.conn.commit()
        # close the connection
        self.conn.close()
        self.conn = None
        
        self.engine.dispose()
        
    def create_db(self):
        db_str = 'postgresql://{username}:{password}@{host}:{port}'.format(username=self.db_admin_user,password=self.db_admin_password,host=self.db_host,port=self.db_port)
        print("Using db connection "+db_str+" for DB creation.")
        
        conn = pg.connect(db_str)
        conn.autocommit = True
        cur = conn.cursor()   
        
        drop_command = "DROP DATABASE IF EXISTS " +self.db_name
        create_command = "CREATE DATABASE " +self.db_name
        cur.execute(drop_command)
        cur.execute(create_command)
        conn.commit()
        
        drop_command = "DROP ROLE IF EXISTS " +self.db_user
        create_command = "CREATE ROLE " +self.db_user +" LOGIN PASSWORD '" + self.db_password +"'"
        cur.execute(drop_command)
        cur.execute(create_command)
        conn.commit()
        
        grant_command_01 = "GRANT USAGE ON SCHEMA public TO "+ self.db_user
        grant_command_02 = "ALTER DEFAULT PRIVILEGES IN SCHEMA public GRANT "+ self.db_user_grants +" ON TABLES TO "+ self.db_user
        cur.execute(grant_command_01)
        cur.execute(grant_command_02)
        conn.commit()
        
        if self.db_schema is not None and "" != self.db_schema:
            drop_command = "DROP SCHEMA IF EXISTS "+ self.db_schema
            create_command = "CREATE SCHEMA "+ self.db_schema
            cur.execute(drop_command)
            cur.execute(create_command)
            conn.commit()
    
        cur.close()
        conn.close()
        
class TableConfig:
    name = None
    content = None
    types = {}
    
    def get_table_name(self, db_config):
        if db_config.db_schema is None or "" is db_config.db_schema:
            return self.name.lower()
        else:
            return db_config.db_schema.lower() + "." + self.name.lower()
    
    
def define_types(table_config, table_fields_config):
    print("Handle table '"+ table_config.name +"'")
    first_column = True
    table_config.content.columns = table_config.content.columns.str.lower()
    
    for column in table_config.content.columns[0:]:
        print("Handle field '"+ table_config.get_table_name(db_config) + "."+ column +"'.")
        if table_fields_config is not None:
            field_config = table_fields_config.get(column, None)
            
            if field_config is not None:
                for key, value in field_config.items():
                    print("Handle field '"+ table_config.name + "."+ column +"' having '"+ str(key) +" = "+ str(value) +"'.")
                    
                    if "format" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of type date.")
                        table_config.content[column] = pd.to_datetime(table_config.content[column], format=value)
                        table_config.content[column] = table_config.content[column].apply(lambda x: x.date())
                        
                        table_config.types[column] = "DATE"
                        if "%H" in key:
                            table_config.types[column] = "TIMESTAMP"
                        
                    elif "numeric" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of numeric type.")
                        table_config.content[column] = pd.to_numeric(table_config.content[column], errors='coerce')
                    elif "type" == key:
                        print("Field '"+ table_config.name +"."+ column +"' is of type = '"+str(value) +"'.'")
                        table_config.content[column] = table_config.content[column].astype(value)
                    else:
                        print("!!!!\Field '"+ table_config.name +"."+ column +"' has an unknown conversion defined '"+ str(key) +" = "+ str(value) +"'.\n!!!!")

        if column not in table_config.types:
            typ = type_mapping.get(str(table_config.content[column].dtype), None)
            
            if typ is not None:
                table_config.types[column] = typ

            else:
                print("!!!!\nThere is not type defined for '"+str(table_config.content[column].dtype) +" in "+ str(type_mapping) +"'.\n!!!!")

            
        if first_column:
            #print("Table "+ table_config.name +" has index "+ column)
            #table_config.content.set_index(column, inplace=True, verify_integrity=True)
            first_column = False
             
                
def create_table(db_config, table_config):
    drop_command = "DROP TABLE IF EXISTS "+ table_config.get_table_name(db_config)
    create_command = "CREATE TABLE IF NOT EXISTS "+ table_config.get_table_name(db_config) +" ("
    #grant_command_01 = "GRANT "+ db_config.db_user_grants +" ON ALL TABLES IN SCHEMA "+ db_config.db_name +" TO "+ db_config.db_user
    #grant_command_01 = "GRANT ALL PRIVILEGES ON DATABASE "+ db_config.db_name +" TO "+ db_config.db_user
    #grant_command_01 = "GRANT "+ db_config.db_user_grants +" PRIVILEGES ON ALL TABLES IN SCHEMA public TO "+ db_config.db_user
    #grant_command_02 = "GRANT "+ db_config.db_user_grants +" PRIVILEGES ON ALL SEQUENCES IN SCHEMA public TO "+ db_config.db_user
    grant_command_01 = "GRANT "+ db_config.db_user_grants +" ON ALL TABLES IN SCHEMA public TO "+ db_config.db_user
    
    first_column = True
    column = table_config.content.columns[0]
    if not table_config.content[column].is_unique:
        create_command += "index INT PRIMARY KEY NOT NULL"
        first_column = False
        
    for column in table_config.content.columns[0:]:
        print("Handle field '"+ table_config.get_table_name(db_config) + "."+ column +"' being of type '"+ str(table_config.content[column].dtype) +"'.")
        
        if not first_column:
            create_command += ","
            
        create_command += column + " "
        create_command += str(table_config.types[column])
        table_name_index = column.find("_id")
        
        if first_column:
            create_command += " PRIMARY KEY NOT NULL"
            table_config.content.set_index(column, inplace=True, verify_integrity=True)
            first_column = False
        elif table_name_index != -1:
            table_name = column[:table_name_index]
            if table_name in db_config.tables:
                create_command += " NOT NULL REFERENCES " + table_name
            else:
                print("Field "+ column +" seems to reference table "+ table_name +" but this table does not exist.")
                
    create_command += ")"
    
    print("Execute "+ drop_command)
    db_config.cur.execute(drop_command)
    print("Execute "+ create_command)
    db_config.cur.execute(create_command)
    print("Execute "+ grant_command_01)
    db_config.cur.execute(grant_command_01)
    #print("Execute "+ grant_command_02)
    #db_config.cur.execute(grant_command_02)
    db_config.conn.commit()
    db_config.tables.add(table_config.name)
    
def add_data(db_config, table_config):
    if db_config.db_schema is None or db_config.db_schema == "":
        table_config.content.to_sql(table_config.name, db_config.engine, if_exists='append', chunksize=1000)
    else:
        table_config.content.to_sql(table_config.name, db_config.engine, schema=db_config.db_schema, if_exists='append', chunksize=1000)

# %%
# unpack the zip file
from shutil import unpack_archive
os.makedirs(zip_file_dir, exist_ok=True)
unpack_archive(zip_file, '.')

db_config = DBConfig()

for root, dirs, files in os.walk(zip_file_dir):
    files.sort()
    for file in files:
        if file.endswith(table_file_ending):
            table_config = TableConfig()
            table_name = os.path.splitext(file)[0]
            table_name_index = table_name.find("_")
            
            if table_name_index != -1 and table_name[:table_name_index].isdigit():
                table_name = table_name[table_name_index+1:]
            
            table_config.name = table_name
            table = pd.read_csv(os.path.join(root, file), delimiter=table_file_delimiter)
            table_config.content = table  
            #print("Read table content of '"+table_config.name +"'.")
            
            define_types(table_config, table_field_configs.get(table_config.name, None))
            create_table(db_config, table_config)
            add_data(db_config, table_config)

# remove data files
from shutil import rmtree
rmtree(zip_file_dir, ignore_errors=True)

db_config.dispose()
# Out:
# Using db connection postgresql://db_admin:db_admin_0815_pw@192.168.0.1:5432 for DB creation.
# Using db connection postgresql://db_admin:db_admin_0815_pw@192.168.0.1:5432/bank_db
# Handle table 'district'
# Handle field 'district.a1'.
# Handle field 'district.a2'.
# Handle field 'district.a3'.
# Handle field 'district.a4'.
# Handle field 'district.a5'.
# Handle field 'district.a6'.
# Handle field 'district.a7'.
# Handle field 'district.a8'.
# Handle field 'district.a9'.
# Handle field 'district.a10'.
# Handle field 'district.a11'.
# Handle field 'district.a12'.
# Handle field 'district.a12' having 'numeric = '.
# Field 'district.a12' is of numeric type.
# Handle field 'district.a13'.
# Handle field 'district.a14'.
# Handle field 'district.a15'.
# Handle field 'district.a15' having 'numeric = '.
# Field 'district.a15' is of numeric type.
# Handle field 'district.a16'.
# Handle field 'district.a1' being of type 'int64'.
# Handle field 'district.a2' being of type 'object'.
# Handle field 'district.a3' being of type 'object'.
# Handle field 'district.a4' being of type 'int64'.
# Handle field 'district.a5' being of type 'int64'.
# Handle field 'district.a6' being of type 'int64'.
# Handle field 'district.a7' being of type 'int64'.
# Handle field 'district.a8' being of type 'int64'.
# Handle field 'district.a9' being of type 'int64'.
# Handle field 'district.a10' being of type 'float64'.
# Handle field 'district.a11' being of type 'int64'.
# Handle field 'district.a12' being of type 'float64'.
# Handle field 'district.a13' being of type 'float64'.
# Handle field 'district.a14' being of type 'int64'.
# Handle field 'district.a15' being of type 'float64'.
# Handle field 'district.a16' being of type 'int64'.
# Execute DROP TABLE IF EXISTS district
# Execute CREATE TABLE IF NOT EXISTS district (a1 INT PRIMARY KEY NOT NULL,a2 TEXT,a3 TEXT,a4 INT,a5 INT,a6 INT,a7 INT,a8 INT,a9 INT,a10 FLOAT,a11 INT,a12 FLOAT,a13 FLOAT,a14 INT,a15 FLOAT,a16 INT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'client'
# Handle field 'client.client_id'.
# Handle field 'client.birth_number'.
# Handle field 'client.district_id'.
# Handle field 'client.client_id' being of type 'int64'.
# Handle field 'client.birth_number' being of type 'int64'.
# Handle field 'client.district_id' being of type 'int64'.
# Execute DROP TABLE IF EXISTS client
# Execute CREATE TABLE IF NOT EXISTS client (client_id INT PRIMARY KEY NOT NULL,birth_number INT,district_id INT NOT NULL REFERENCES district)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'account'
# Handle field 'account.account_id'.
# Handle field 'account.district_id'.
# Handle field 'account.frequency'.
# Handle field 'account.date'.
# Handle field 'account.date' having 'format = %y%m%d'.
# Field 'account.date' is of type date.
# Handle field 'account.account_id' being of type 'int64'.
# Handle field 'account.district_id' being of type 'int64'.
# Handle field 'account.frequency' being of type 'object'.
# Handle field 'account.date' being of type 'object'.
# Execute DROP TABLE IF EXISTS account
# Execute CREATE TABLE IF NOT EXISTS account (account_id INT PRIMARY KEY NOT NULL,district_id INT NOT NULL REFERENCES district,frequency TEXT,date DATE)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'loan'
# Handle field 'loan.loan_id'.
# Handle field 'loan.account_id'.
# Handle field 'loan.date'.
# Handle field 'loan.date' having 'format = %y%m%d'.
# Field 'loan.date' is of type date.
# Handle field 'loan.amount'.
# Handle field 'loan.duration'.
# Handle field 'loan.payments'.
# Handle field 'loan.status'.
# Handle field 'loan.loan_id' being of type 'int64'.
# Handle field 'loan.account_id' being of type 'int64'.
# Handle field 'loan.date' being of type 'object'.
# Handle field 'loan.amount' being of type 'int64'.
# Handle field 'loan.duration' being of type 'int64'.
# Handle field 'loan.payments' being of type 'float64'.
# Handle field 'loan.status' being of type 'object'.
# Execute DROP TABLE IF EXISTS loan
# Execute CREATE TABLE IF NOT EXISTS loan (loan_id INT PRIMARY KEY NOT NULL,account_id INT NOT NULL REFERENCES account,date DATE,amount INT,duration INT,payments FLOAT,status TEXT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'orders'
# Handle field 'orders.orders_id'.
# Handle field 'orders.account_id'.
# Handle field 'orders.bank_to'.
# Handle field 'orders.account_to'.
# Handle field 'orders.amount'.
# Handle field 'orders.k_symbol'.
# Handle field 'orders.orders_id' being of type 'int64'.
# Handle field 'orders.account_id' being of type 'int64'.
# Handle field 'orders.bank_to' being of type 'object'.
# Handle field 'orders.account_to' being of type 'int64'.
# Handle field 'orders.amount' being of type 'float64'.
# Handle field 'orders.k_symbol' being of type 'object'.
# Execute DROP TABLE IF EXISTS orders
# Execute CREATE TABLE IF NOT EXISTS orders (orders_id INT PRIMARY KEY NOT NULL,account_id INT NOT NULL REFERENCES account,bank_to TEXT,account_to INT,amount INT,k_symbol TEXT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'disp'
# Handle field 'disp.disp_id'.
# Handle field 'disp.client_id'.
# Handle field 'disp.account_id'.
# Handle field 'disp.type'.
# Handle field 'disp.disp_id' being of type 'int64'.
# Handle field 'disp.client_id' being of type 'int64'.
# Handle field 'disp.account_id' being of type 'int64'.
# Handle field 'disp.type' being of type 'object'.
# Execute DROP TABLE IF EXISTS disp
# Execute CREATE TABLE IF NOT EXISTS disp (disp_id INT PRIMARY KEY NOT NULL,client_id INT NOT NULL REFERENCES client,account_id INT NOT NULL REFERENCES account,type TEXT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# Handle table 'card'
# Handle field 'card.card_id'.
# Handle field 'card.disp_id'.
# Handle field 'card.type'.
# Handle field 'card.issued'.
# Handle field 'card.issued' having 'format = %y%m%d %H:%M:%S'.
# Field 'card.issued' is of type date.
# Handle field 'card.card_id' being of type 'int64'.
# Handle field 'card.disp_id' being of type 'int64'.
# Handle field 'card.type' being of type 'object'.
# Handle field 'card.issued' being of type 'object'.
# Execute DROP TABLE IF EXISTS card
# Execute CREATE TABLE IF NOT EXISTS card (card_id INT PRIMARY KEY NOT NULL,disp_id INT NOT NULL REFERENCES disp,type TEXT,issued DATE)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Handle table 'trans'
# Handle field 'trans.trans_id'.
# Handle field 'trans.account_id'.
# Handle field 'trans.date'.
# Handle field 'trans.date' having 'format = %y%m%d'.
# Field 'trans.date' is of type date.
# Handle field 'trans.type'.
# Handle field 'trans.operation'.
# Handle field 'trans.amount'.
# Handle field 'trans.balance'.
# Handle field 'trans.k_symbol'.
# Handle field 'trans.bank'.
# Handle field 'trans.account'.
# Handle field 'trans.trans_id' being of type 'int64'.
# Handle field 'trans.account_id' being of type 'int64'.
# Handle field 'trans.date' being of type 'object'.
# Handle field 'trans.type' being of type 'object'.
# Handle field 'trans.operation' being of type 'object'.
# Handle field 'trans.amount' being of type 'float64'.
# Handle field 'trans.balance' being of type 'float64'.
# Handle field 'trans.k_symbol' being of type 'object'.
# Handle field 'trans.bank' being of type 'object'.
# Handle field 'trans.account' being of type 'float64'.
# Execute DROP TABLE IF EXISTS trans
# Execute CREATE TABLE IF NOT EXISTS trans (trans_id INT PRIMARY KEY NOT NULL,account_id INT NOT NULL REFERENCES account,date DATE,type TEXT,operation TEXT,amount INT,balance FLOAT,k_symbol TEXT,bank TEXT,account FLOAT)
# Execute GRANT SELECT ON ALL TABLES IN SCHEMA public TO db_user
