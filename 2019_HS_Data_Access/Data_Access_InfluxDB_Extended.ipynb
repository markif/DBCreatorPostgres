# %% [markdown]
# # Data Access InfluxDB
#
# This document provides an introduction on how to access the [InfluxDB](https://docs.influxdata.com/influxdb) database used in Challenge 5.

# %% [markdown]
# First we need to import the necessary python modules (we assume that the necessary OS dependencies are already installed).

# %%
# install the modules on the OS
# !pip install influxdb

# import the modules
import pandas as pd
from influxdb import DataFrameClient
# Out:
# Requirement already satisfied: influxdb in /opt/conda/lib/python3.7/site-packages (5.2.2)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from influxdb) (1.12.0)
# Requirement already satisfied: requests>=2.17.0 in /opt/conda/lib/python3.7/site-packages (from influxdb) (2.21.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in /opt/conda/lib/python3.7/site-packages (from influxdb) (2.8.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from influxdb) (2019.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=2.17.0->influxdb) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=2.17.0->influxdb) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=2.17.0->influxdb) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=2.17.0->influxdb) (1.24.2)

# %% [markdown]
# Next we define the database connection information.

# %%
# define the database connection string
DB_HOST = '86.119.36.94' 
DB_PORT = 8086
DB_DBNAME = 'meteorology'
stations = ['mythenquai', 'tiefenbrunnen']

print(DB_HOST +":"+str(DB_PORT))
# Out:
# 86.119.36.94:8086

# %% [markdown]
# ### DataFrameClient
#
# InfluxDB provides a [DataFrameClient](https://influxdb-python.readthedocs.io/en/latest/examples.html#tutorials-pandas) that can query data and store the result in [Pandas Dataframe](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html).

# %%
client = DataFrameClient(host=DB_HOST, port=DB_PORT, database=DB_DBNAME)
client.switch_database(DB_DBNAME)

# %% [markdown]
# Let's query some data using [InfluxQL](https://docs.influxdata.com/influxdb/v1.7/query_language/data_exploration/) (InfluxDB's query language).

# %%
query = "SELECT COUNT(air_temperature) FROM \"{}\",\"{}\" tz('Europe/Zurich')".format(stations[0], stations[1])
result = client.query(query)
print(result[stations[0]])
print(result[stations[1]])
# Out:
#                             count
# 1970-01-01 01:00:00+01:00  634661
#                             count
# 1970-01-01 01:00:00+01:00  628207

# %% [markdown]
# Internally, InfluxDB stores time in [UTC](https://en.wikipedia.org/wiki/Coordinated_Universal_Time). Depending on the season (daylight saving time), our timezone (Zurich) has an offset of +02:00 or +01:00. Therefore, it is important to set this offset in the query. Otherwise, InfluxDB's query engine would have to make assumptions on which time zone it should use.

# %%
start_time = '2019-07-23T00:00:00+02:00'
end_time = '2019-07-24T00:00:00+02:00'
query = "SELECT COUNT(air_temperature) FROM \"{}\",\"{}\" WHERE time >= '{}' AND time <= '{}' tz('Europe/Zurich')".format(stations[0], stations[1], start_time, end_time)
result = client.query(query)
print(result[stations[0]])
print(result[stations[1]])
# Out:
#                            count
# 2019-07-23 00:00:00+02:00    145
#                            count
# 2019-07-23 00:00:00+02:00    145

# %%
query = "SELECT air_temperature FROM \"{}\",\"{}\" WHERE time >= '{}' AND time <= '{}' tz('Europe/Zurich')".format(stations[0], stations[1], start_time, end_time)
result = client.query(query)
print(result[stations[0]])
print(result[stations[1]])
# Out:
#                            air_temperature
# 2019-07-23 00:00:00+02:00             22.2
# 2019-07-23 00:10:00+02:00             22.1
# 2019-07-23 00:20:00+02:00             21.9
# 2019-07-23 00:30:00+02:00             21.8
# 2019-07-23 01:10:00+02:00             21.9
# 2019-07-23 01:20:00+02:00             21.8
# 2019-07-23 01:30:00+02:00             21.7
# 2019-07-23 01:40:00+02:00             21.6
# 2019-07-23 01:50:00+02:00             21.5
# 2019-07-23 02:00:00+02:00             21.4
# 2019-07-23 02:10:00+02:00             21.3
# 2019-07-23 02:20:00+02:00             21.1
# 2019-07-23 02:30:00+02:00             21.0
# 2019-07-23 02:40:00+02:00             21.0
# 2019-07-23 02:50:00+02:00             20.9
# 2019-07-23 03:00:00+02:00             20.9
# 2019-07-23 03:10:00+02:00             20.8
# 2019-07-23 03:20:00+02:00             20.7
# 2019-07-23 03:30:00+02:00             20.6
# 2019-07-23 03:40:00+02:00             20.6
# 2019-07-23 03:50:00+02:00             20.5
# 2019-07-23 04:00:00+02:00             20.4
# 2019-07-23 04:10:00+02:00             20.3
# 2019-07-23 04:20:00+02:00             20.3
# 2019-07-23 04:30:00+02:00             20.2
# 2019-07-23 04:40:00+02:00             20.2
# 2019-07-23 04:50:00+02:00             20.1
# ...                                    ...
# 2019-07-23 19:10:00+02:00             32.9
# 2019-07-23 19:20:00+02:00             32.9
# 2019-07-23 19:30:00+02:00             32.8
# 2019-07-23 19:40:00+02:00             32.8
# 2019-07-23 19:50:00+02:00             32.7
# 2019-07-23 20:00:00+02:00             32.6
# 2019-07-23 20:10:00+02:00             32.4
# 2019-07-23 20:20:00+02:00             32.1
# 2019-07-23 20:30:00+02:00             31.9
# 2019-07-23 20:40:00+02:00             31.6
# 2019-07-23 20:50:00+02:00             31.2
# 2019-07-23 21:00:00+02:00             30.8
# 2019-07-23 21:10:00+02:00             30.3
# 2019-07-23 21:20:00+02:00             29.8
# 2019-07-23 21:30:00+02:00             29.3
# 2019-07-23 21:40:00+02:00             28.9
# 2019-07-23 21:50:00+02:00             28.6
# 2019-07-23 22:00:00+02:00             28.3
# 2019-07-23 22:10:00+02:00             28.0
# 2019-07-23 22:20:00+02:00             27.5
# 2019-07-23 22:30:00+02:00             27.2
# 2019-07-23 22:40:00+02:00             26.9
# 2019-07-23 22:50:00+02:00             26.6
# 2019-07-23 23:00:00+02:00             26.4
# 2019-07-23 23:10:00+02:00             26.2
# 2019-07-23 23:20:00+02:00             26.0
# 2019-07-23 23:30:00+02:00             25.8
# 2019-07-23 23:40:00+02:00             25.6
# 2019-07-23 23:50:00+02:00             25.4
# 2019-07-24 00:00:00+02:00             25.2
#
# [145 rows x 1 columns]

# %% [markdown]
# ### InfluxDB REST API
#
# Alternatively, it is also possible to use InfluxDB's [Query REST API](https://docs.influxdata.com/influxdb/v1.7/tools/api/#query-http-endpoint) (quick intro on REST please see [here](https://www.restapitutorial.com/lessons/whatisrest.html) and [here](https://www.restapitutorial.com/lessons/httpmethods.html)). This can be helpful for programming languages for which InfluxDB does not provide a client (e.g. [R](https://community.influxdata.com/t/how-should-i-read-influxdb-from-r/860/2))

# %% [markdown]
# Import the necessary python modules (we assume that the necessary OS dependencies are already installed)

# %%
# install the modules on the OS
# !pip install jsonpath-ng

# import the modules
import requests
import json
from jsonpath_ng import jsonpath, parse

# setup the base url
base_url = "http://{}:{}/query?db={}".format(DB_HOST, DB_PORT, DB_DBNAME)
print(base_url)
# Out:
# Requirement already satisfied: jsonpath-ng in /opt/conda/lib/python3.7/site-packages (1.4.3)
# Requirement already satisfied: ply in /opt/conda/lib/python3.7/site-packages (from jsonpath-ng) (3.11)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from jsonpath-ng) (1.12.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from jsonpath-ng) (4.4.0)
# http://86.119.36.94:8086/query?db=meteorology

# %%
query = "SELECT COUNT(air_temperature) FROM \"{}\" tz('Europe/Zurich')".format(stations[0])
response = requests.get(base_url, params={"q": query})
if not response.ok:
    response.raise_for_status()

json_response = json.loads(response.content)
print(json_response)
# Out:
# {'results': [{'statement_id': 0, 'series': [{'name': 'mythenquai', 'columns': ['time', 'count'], 'values': [['1970-01-01T01:00:00+01:00', 634661]]}]}]}

# %% [markdown]
# Extract data using Python data structures (like dicts and arrays) directly.

# %%
values = json_response["results"][0]["series"][0]["values"]
print(values)
# Out:
# [['1970-01-01T01:00:00+01:00', 634661]]

# %% [markdown]
# Alternatively, use [JSONPath](https://pypi.org/project/jsonpath-ng) to access/query the data of interest.

# %%
accessor = parse('results[*].series[*].name|columns|values')
accessor_value = parse('results[*].series[*].values')
acc_result = [match.value for match in accessor.find(json_response)]
value_result = [match.value for match in accessor_value.find(json_response)]
print(acc_result)
print(value_result)
# Out:
# ['mythenquai', ['time', 'count'], [['1970-01-01T01:00:00+01:00', 634661]]]
# [[['1970-01-01T01:00:00+01:00', 634661]]]

# %% [markdown]
# Another query

# %%
query = "SELECT air_temperature FROM \"{}\" WHERE time >= '{}' AND time <= '{}' tz('Europe/Zurich')".format(stations[0], start_time, end_time)
response = requests.get(base_url, params={"q": query})
if not response.ok:
    response.raise_for_status()

json_response = json.loads(response.content)

# %%
values = json_response["results"][0]["series"][0]["values"]
print(values)
# Out:
# [['2019-07-23T00:00:00+02:00', 22.2], ['2019-07-23T00:10:00+02:00', 22.1], ['2019-07-23T00:20:00+02:00', 21.9], ['2019-07-23T00:30:00+02:00', 21.8], ['2019-07-23T00:40:00+02:00', 21.7], ['2019-07-23T00:50:00+02:00', 21.5], ['2019-07-23T01:00:00+02:00', 21.4], ['2019-07-23T01:10:00+02:00', 21.2], ['2019-07-23T01:20:00+02:00', 21.1], ['2019-07-23T01:30:00+02:00', 20.9], ['2019-07-23T01:40:00+02:00', 20.8], ['2019-07-23T01:50:00+02:00', 20.7], ['2019-07-23T02:00:00+02:00', 20.6], ['2019-07-23T02:10:00+02:00', 20.6], ['2019-07-23T02:20:00+02:00', 20.5], ['2019-07-23T02:30:00+02:00', 20.4], ['2019-07-23T02:40:00+02:00', 20.2], ['2019-07-23T02:50:00+02:00', 20.1], ['2019-07-23T03:00:00+02:00', 20.1], ['